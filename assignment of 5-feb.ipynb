# %%
'''Q1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.

Class:- Class is blue-prit of any realworld object.and otherword it ia sample of any product.


object:-object is a  sample of any class we create more than object based on requirment.

'''

#Example of class
class Student:
    def __init__(self,n,r):
        self.n=n
        self.r=r
    def S_details(self):
        print("\n\tStudent_Name is: ",self.n)
        print("\n\tStudent_Name is: ",self.r)
obj=Student("Alok Kumar",26)
print(obj.S_details())   

'''Q2. Name the four pillars of OOPs
Ans:
1.abstraction
2.inheritance
3.encapsulation
4.polymorphism


'''

'''Q3. Explain why the __init__() function is used. Give a suitable example
Ans:- __init__() function is also known as constructor with creation of object __init__ ()function is execute.
except self keyword .self keyword is implicit parameter provided by pvm. 
 '''

 #Example of __init__.

class Course:
    def __init__(self,cn,cf):
        self.cn=cn
        self.cf=cf
    def Course_details(self):
        print("\n\tCourse Name: ",self.cn)
        print("\n\tCourse Fee: ",self.cf)
obj=Course("Data-Science",3500) 
print(obj.Course_details())  

'''Q4. Why self is used in OOPs?
Ans:- self keyword is implicit parameter provided by pvm.in otherword self is pinter to point 
variable.
'''


'''Q5. What is inheritance? Give an example for each type of inheritance
Ans:- Inheritance is a very important features in python .it is derived from other class.
to inherit all properties of other class.
Basically two class define the use inheritance concept first class is called super class or paren class
and second called sub class or child class.sub class inherit super class that means all features of super class 
to access by sub class.


'''
#Example of inheritance
class a:
    def __init__(self,n1):
        self.n=n1
    def square(self):
        return "Square of inputted number:=",self.n*self.n 
class b(a):
    def cube(self):
        return "Cube of inputted number:=",self.n*self.n*self.n
obj=b(5)
print(obj.square())
